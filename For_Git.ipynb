# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data.csv', sep=',')
# Out:
#         device_type                              event_id  user_id  \
# 0           desktop  cd4192b5-3709-46dd-a601-444dde3e762d        1
# 1           desktop  dd8a2b1a-9268-4930-b414-cfbd9cda16d7        2
# 2           desktop  0416ecb1-e53a-474b-9cbc-ca3009dbaed6        3
# 3           desktop  d3e6cb84-74bb-47b5-bfc3-5118d24f7e40        3
# 4           desktop  58d5a95d-4885-485b-a571-f24900cc0bf2        3
# ...             ...                                   ...      ...
# 6999995     desktop  099636b2-0e6a-41a9-b6d5-679f03c902af  2108032
# 6999996     desktop  bd75f657-ee5b-46c1-8f06-87630651d434  2108033
# 6999997     desktop  3c400cf9-c78c-4da9-85ad-b37e455d7252  2108033
# 6999998     desktop  37d99603-7ef3-4dd9-a3f5-5f097aa7e2ef  2108034
# 6999999     desktop  eb958ba0-9174-4b47-b3ed-16498a3e891b  2108035
#
#          user_is_authorized  location_id         create_timestamp  product_id  \
# 0                         0          968  2024-06-02 10:46:21.989       68390
# ...

# %% [markdown]
# # Предварительный анализ

# %% [markdown]
# ### Таблица корреляции

# %%
df2 = df.copy()
df2 = df2.select_dtypes(include=['float64', 'int64'])
mt = df2.corr()

# %%
plt.figure(figsize=(12, 10))
sns.set_theme(style='darkgrid')
heatmap = sns.heatmap(mt, annot=True, fmt=".2f", cmap='coolwarm', square=True,
                       linewidths=0.5, cbar_kws={"shrink": .8}, )
plt.title('Матрица Корреляций', fontsize=20)
plt.show()
cmap='viridis'

# %% [markdown]
# ### График количества заказов в день, когда товар доступен к получению сейчас и нет

# %% [markdown]
# # Очистка от выбросов

# %% [markdown]
# # Математиское подтверждение
